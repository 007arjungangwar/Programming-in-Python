# %% [markdown]
# <a href="https://colab.research.google.com/github/007arjungangwar/Programming-in-Python/blob/main/try_0902_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string1='hello'
string2="Hello World"
string3='''Hi what you are doing tomorrow.
We can go for a movie if you dont have any problem.
'''
print(string1)
print(string2)
print(string3)
# Out:
# hello
# Hello World
# Hi what you are doing tomorrow.
# We can go for a movie if you dont have any problem.

# %%
#by str()

fourth=str(12345)
fourth
# Out:
# '12345'

# %%
text="Python"
print(text[0])
print(text[1])
print(text[2])
print(text[3])
print(text[4])
print(text[5])
# Out:
# P
# y
# t
# h
# o
# n

# %%
print(text[-1])
print(text[-2])
print(text[-3])
print(text[-4])
print(text[-5])
print(text[-6])
# Out:
# n
# o
# h
# t
# y
# P

# %%
for i in text:
  print(i)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
for i in range(len(text)):
  print(text[i])
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %%
text="Hello World"

print(text[0:2])
print(text[0:3])
print(text[0:5:2])

print(text[:])
print(text[::2])
print(text[::2])

print(text[5:0])
print(text[5:0:2])
print(text[6:0:-1])


print(text[::-1])
# Out:
# He
# Hel
# Hlo
# Hello World
# HloWrd
# HloWrd
#
#
# W olle
# dlroW olleH

# %%
first_name="Arjun"
last_name="Gangwar"

full_name=first_name+last_name
print(full_name)


full_name=first_name+" "+last_name
print(full_name)
# Out:
# ArjunGangwar
# Arjun Gangwar

# %%
print("*"*20)
print("hello!"*8)
# Out:
# ********************
# hello!hello!hello!hello!hello!hello!hello!hello!

# %%
sentence="I" + "Love" + "Python"+"Programming"
print(sentence)

sentence="I" + " Love" + " Python"+" Programming"
print(sentence)
# Out:
# ILovePythonProgramming
# I Love Python Programming

# %%
text_str="Hello"
list_str=list("Hello")
print(text_str,type(text_str),id(text_str))
print(list_str,type(list_str),id(list_str))
# Out:
# Hello <class 'str'> 133561977952160
# ['H', 'e', 'l', 'l', 'o'] <class 'list'> 133561969101696

# %%
# text_str[0]="h"
list_str[0]="h"
list_str
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
print(list_str,type(list_str),id(list_str))
# Out:
# ['h', 'e', 'l', 'l', 'o'] <class 'list'> 133561969101696

# %%
new_text="h"+text_str[1:]
new_text
print(new_text,type(new_text),id(new_text))
print(text_str,type(text_str),id(text_str))
# Out:
# hello <class 'str'> 133561977988768
# Hello <class 'str'> 133561977952160

# %%
sec_text=text_str.replace("H","K")
print(sec_text,type(sec_text),id(sec_text))
# Out:
# Kello <class 'str'> 133561973163568

# %%
for i in text:
  print(f"text[len(text{i})]{i}")
# Out:
# text[len(textH)]H
# text[len(texte)]e
# text[len(textl)]l
# text[len(textl)]l
# text[len(texto)]o
# text[len(text )]
# text[len(textW)]W
# text[len(texto)]o
# text[len(textr)]r
# text[len(textl)]l
# text[len(textd)]d

# %%
for i in text:
  print(text[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2895881190.py in <cell line: 0>()
#       1 for i in text:
# ----> 2   print(text[i])
#
# TypeError: string indices must be integers, not 'str'

# %%
for char in text[::2]:
  print(f"{char}")
# Out:
# H
# l
# o
# W
# r
# d

# %%
# 5. Membership Operations
quote = "To be or not to be"
print("’be’ in quote:", "be" in quote) # True
print("’python’ in quote:", "python" in quote) # False
print("’BE’ in quote:", "BE" in quote) # False (case-sensitive)
print("’to’ not in quote:", "to" not in quote) # True (case-sensitive)
# Out:
# ’be’ in quote: True
# ’python’ in quote: False
# ’BE’ in quote: False
# ’to’ not in quote: False
